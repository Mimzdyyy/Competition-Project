# %%
import pandas as pd # linear algebra
import numpy as np # data processing
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv("train.csv")
dataset
# Out:
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 0             149           393           634        2741
# 1              18            77          2722        1815
# 2             621            37           954        3763
# 3             103           963           143         294
# 4             669           403          2842        5593
# ..            ...           ...           ...         ...
# 428           620           389          2714        1938
# 429           721           955          2565        3756
# 430            26           940          1781        3926
# 431           217           246           607        2060
# 432           743          1129           661         444
#
#       ROA(C) before interest and depreciation before interest  \
# 0                                             0.450154
# 1                                             0.494126
# 2                                             0.358797
# ...

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0.3', 'Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0',
#        ' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' ROA(B) before interest and depreciation after tax',
#        ' Operating Gross Margin', ' Realized Sales Gross Margin',
#        ' Operating Profit Rate', ' Pre-tax net Interest Rate',
#        ' After-tax net Interest Rate',
#        ' Non-industry income and expenditure/revenue',
#        ' Continuous interest rate (after tax)', ' Operating Expense Rate',
#        ' Research and development expense rate', ' Cash flow rate',
#        ' Interest-bearing debt interest rate', ' Tax rate (A)',
#        ' Net Value Per Share (B)', ' Net Value Per Share (A)',
#        ' Net Value Per Share (C)', ' Persistent EPS in the Last Four Seasons',
#        ' Cash Flow Per Share', ' Revenue Per Share (Yuan ¥)',
#        ' Operating Profit Per Share (Yuan ¥)',
# ...

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0.3                                                0
# Unnamed: 0.2                                                0
# Unnamed: 0.1                                                0
# Unnamed: 0                                                  0
#  ROA(C) before interest and depreciation before interest    0
#                                                            ..
#  Degree of Financial Leverage (DFL)                         0
#  Interest Coverage Ratio (Interest expense to EBIT)         0
#  Net Income Flag                                            0
#  Equity to Liability                                        0
# Bankrupt?                                                   0
# Length: 100, dtype: int64

# %%
X = dataset.drop('Bankrupt?', axis=1)
y = dataset['Bankrupt?']

# %%
def train_test_validation(dataset):
    X = dataset.drop('Bankrupt?', axis=1)
    y = dataset['Bankrupt?']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=0.25, random_state=42)
    train = pd.concat([X_train,y_train], axis=1)
    validation = pd.concat([X_validation, y_validation], axis=1)
    test = pd.concat([X_test, y_test], axis=1)
    return train, test, validation

# %%
train, test, validation = train_test_validation(dataset)

# %%
train
# Out:
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 23            129           122          2591         461
# 251           232           667           305        3346
# 177           726           690          2427        3339
# 244           852           290           975        3814
# 270           737          1138           526        1015
# ..            ...           ...           ...         ...
# 135           560            16           616        2334
# 122           541           319           639        5070
# 185           604           417          3392        5820
# 257           539          1337          2149         819
# 129           127          1416          3237        3281
#
#       ROA(C) before interest and depreciation before interest  \
# 23                                            0.438454
# 251                                           0.549456
# 177                                           0.545264
# ...

# %%
test
# Out:
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 425           647             2           117         671
# 75             35           474           172        4300
# 181           755          1619          1890        5618
# 30             48           264          1440        4335
# 364           111           770          3077        4713
# ..            ...           ...           ...         ...
# 386           730          1588          2662        6663
# 318            94            66          2348        6164
# 218           273           288          2865        4568
# 338            11           696          2813        2403
# 184           105          1426           334        3865
#
#       ROA(C) before interest and depreciation before interest  \
# 425                                           0.554673
# 75                                            0.558231
# 181                                           0.500756
# ...

# %%
validation
# Out:
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 146           243          1282           925        1769
# 48            693           826           190        3253
# 407            83           238          2268        1243
# 32            642           293          2155        1772
# 35            188          1671           388        5507
# ..            ...           ...           ...         ...
# 284           354           520           613         732
# 373           307          1713          1120        1814
# 409           674           556          1458        1896
# 209           808          1081           294        6655
# 403           427          1300           164        3013
#
#       ROA(C) before interest and depreciation before interest  \
# 146                                           0.482036
# 48                                            0.460098
# 407                                           0.508019
# ...

# %%
train.to_csv("train.csv")
validation.to_csv("validation.csv")
test.to_csv("test.csv")

# %%
train.isna()
# Out:
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 23          False         False         False       False
# 251         False         False         False       False
# 177         False         False         False       False
# 244         False         False         False       False
# 270         False         False         False       False
# ..            ...           ...           ...         ...
# 135         False         False         False       False
# 122         False         False         False       False
# 185         False         False         False       False
# 257         False         False         False       False
# 129         False         False         False       False
#
#       ROA(C) before interest and depreciation before interest  \
# 23                                               False
# 251                                              False
# 177                                              False
# ...

# %%
pd.concat([dataset, train, validation], axis=0)
# Out:
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 0             149           393           634        2741
# 1              18            77          2722        1815
# 2             621            37           954        3763
# 3             103           963           143         294
# 4             669           403          2842        5593
# ..            ...           ...           ...         ...
# 284           354           520           613         732
# 373           307          1713          1120        1814
# 409           674           556          1458        1896
# 209           808          1081           294        6655
# 403           427          1300           164        3013
#
#       ROA(C) before interest and depreciation before interest  \
# 0                                             0.450154
# 1                                             0.494126
# 2                                             0.358797
# ...

# %%
#First take care of the '?' in the dataset
dataset.rename(columns={'Bankrupt?':'Bankrupt'},inplace=True)
dataset
# Out:
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 0             149           393           634        2741
# 1              18            77          2722        1815
# 2             621            37           954        3763
# 3             103           963           143         294
# 4             669           403          2842        5593
# ..            ...           ...           ...         ...
# 428           620           389          2714        1938
# 429           721           955          2565        3756
# 430            26           940          1781        3926
# 431           217           246           607        2060
# 432           743          1129           661         444
#
#       ROA(C) before interest and depreciation before interest  \
# 0                                             0.450154
# 1                                             0.494126
# 2                                             0.358797
# ...

# %%
#fix the space before the numbers in all columns
i = 0
for i in range(len(dataset.columns)): 
    old_name = dataset.columns[i]
    new_name = dataset.columns[i].strip().replace(" ", "_")

    dataset.rename(columns={old_name: new_name}, inplace = True)

    print(dataset.columns[i], ":", "Mean:", dataset[dataset.columns[i]].mean())
# Out:
# Unnamed:_0.3 : Mean: 435.9214780600462
# Unnamed:_0.2 : Mean: 839.0508083140877
# Unnamed:_0.1 : Mean: 1793.8221709006928
# Unnamed:_0 : Mean: 3403.256351039261
# ROA(C)_before_interest_and_depreciation_before_interest : Mean: 0.5043124232940099
# ROA(A)_before_interest_and_%_after_tax : Mean: 0.5565117351835946
# ROA(B)_before_interest_and_depreciation_after_tax : Mean: 0.5526389875775334
# Operating_Gross_Margin : Mean: 0.6087743537546739
# Realized_Sales_Gross_Margin : Mean: 0.6087754688933408
# Operating_Profit_Rate : Mean: 0.9988712831949865
# Pre-tax_net_Interest_Rate : Mean: 0.7971292991830282
# After-tax_net_Interest_Rate : Mean: 0.8090598287014718
# Non-industry_income_and_expenditure/revenue : Mean: 0.3032743336113035
# Continuous_interest_rate_(after_tax) : Mean: 0.7815432591380134
# Operating_Expense_Rate : Mean: 2202900230.9471993
# Research_and_development_expense_rate : Mean: 1833053579.67677
# Cash_flow_rate : Mean: 0.4677928656565505
# ...

# %%
dataset
# Out:
#      Unnamed:_0.3  Unnamed:_0.2  Unnamed:_0.1  Unnamed:_0  \
# 0             149           393           634        2741
# 1              18            77          2722        1815
# 2             621            37           954        3763
# 3             103           963           143         294
# 4             669           403          2842        5593
# ..            ...           ...           ...         ...
# 428           620           389          2714        1938
# 429           721           955          2565        3756
# 430            26           940          1781        3926
# 431           217           246           607        2060
# 432           743          1129           661         444
#
#      ROA(C)_before_interest_and_depreciation_before_interest  \
# 0                                             0.450154
# 1                                             0.494126
# 2                                             0.358797
# ...

# %%
# Checking number of rows and columns 
print("Number of Rows:", dataset.shape[0])
print("Number of Columns:", dataset.shape[1])

# Checking percentage of null values
print("*****Percentage of Null Values*****")
print(round(dataset.isnull().sum() * 100/dataset.shape[0]))
# Out:
# Number of Rows: 433
# Number of Columns: 100
# *****Percentage of Null Values*****
# Unnamed:_0.3                                               0.0
# Unnamed:_0.2                                               0.0
# Unnamed:_0.1                                               0.0
# Unnamed:_0                                                 0.0
# ROA(C)_before_interest_and_depreciation_before_interest    0.0
#                                                           ...
# Degree_of_Financial_Leverage_(DFL)                         0.0
# Interest_Coverage_Ratio_(Interest_expense_to_EBIT)         0.0
# Net_Income_Flag                                            0.0
# Equity_to_Liability                                        0.0
# Bankrupt                                                   0.0
# Length: 100, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corr = dataset.corr(method='spearman').round(decimals=2)
matrix = np.triu(corr)

fig, ax = plt.subplots(figsize=(20, 10))
ax = sns.heatmap(corr, mask=matrix)
display(corr)
# Out:
#                                                     Unnamed:_0.3  \
# Unnamed:_0.3                                                1.00
# Unnamed:_0.2                                               -0.02
# Unnamed:_0.1                                                0.03
# Unnamed:_0                                                  0.07
# ROA(C)_before_interest_and_depreciation_before_...          0.06
# ...                                                          ...
# Degree_of_Financial_Leverage_(DFL)                         -0.07
# Interest_Coverage_Ratio_(Interest_expense_to_EBIT)         -0.10
# Net_Income_Flag                                              NaN
# Equity_to_Liability                                         0.02
# Bankrupt                                                    0.03
#
#                                                     Unnamed:_0.2  \
# Unnamed:_0.3                                               -0.02
# ...

# %%
#drop columns current 
#ratio,corraliability, total net worth, current liability to assets,  net income, roa(a), operating profit rate, after-tax net interest rate, net income to stockholder's Equity, Net Income Flag,

# %%
from sklearn.model_selection import train_test_split
x_train1,x_test1,y_train1,y_test1=train_test_split(dataset1,label1,test_size=0.33,random_state=0)
from sklearn import svm
model=svm.OneClassSVM(kernel='rbf',nu=1,gamma=0.00001)
import time
debut=time.time()
model.fit(x_train1)
fin=time.time()-debut

# %%
# runtime
import timeit

# Data visualization
import plotly.express as px
import plotly.graph_objects as go

# preprocessing
from sklearn.feature_selection import RFE
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler, Normalizer

# Ml model
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier

np.warnings.filterwarnings('ignore')

# %%
# training set
X = dataset.iloc[:,1:].values
y = dataset.iloc[:,0].values.reshape(-1, 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# determining optimal number of features
n_features = [5, 10, 15, 20, 25, 30, 35, 40]
for i in n_features:
    # Building the model based feature selection
    select = RFE(RandomForestClassifier(n_estimators=100, random_state=42), n_features_to_select=i)

    select.fit(X_train, y_train)

    mask = select.get_support()

    X_train_rfe = select.transform(X_train)
    X_test_rfe = select.transform(X_test)

    score = RandomForestClassifier().fit(X_train_rfe, y_train).score(X_test_rfe, y_test)
    
    print("Test score: {:.3f}".format(score), " number of features: {}".format(i))

# %%
select = RFE(RandomForestClassifier(n_estimators=100, random_state=42), n_features_to_select=15)

select.fit(X_train, y_train)

mask = select.get_support()

X_train_rfe = select.transform(X_train)
X_test_rfe = select.transform(X_test)

score = RandomForestClassifier().fit(X_train_rfe, y_train).score(X_test_rfe, y_test)

print("Test score: {:.3f}".format(score), " number of features: {}".format(15))

features = pd.DataFrame({'features':list(bank.iloc[:,1:].keys()), 'select':list(mask)})
features = list(features[features['select']==True]['features'])
features.append('Bankrupt?')

# %%
dataset = dataset[features]
dataset

# %%
bank.hist(figsize=(20,20), edgecolor='white')
plt.sho
#Most of the data is rich on outliers, and in some other the values are located in just one bin. 
#Let's take a closer look at ' Non-industry income and expenditure/revenue'w()

# %%
bins = pd.cut(dataset[' Non-industry income and expenditure/revenue'], bins=10)
bins = pd.DataFrame(bins)
bins.value_counts()

# %%
lower = dataset[' Non-industry income and expenditure/revenue'] >0.3025
upper = dataset[' Non-industry income and expenditure/revenue'] <0.3045

close = dataset[lower & upper]
print('Rows with outliers: {}'.format(dataset.shape[0]))
print('Rows withou outliers: {}'.format(close.shape[0]))
print('information lost = {} rows'.format(dataset.shape[0]-close.shape[0]))
close[' Non-industry income and expenditure/revenue'].hist(edgecolor='white')
